# %%
#Break

# %%
x=0
while x<3:
    print(x)
    if x==1:
        break
    x=x+1
# Out:
# 0
# 1

# %%
x=0
while x<3:
    print(x)
    if x==1:
        break
    x=x+1
# Out:
# 0
# 1

# %%
x=0
while x<3:
    print(x)
    
    x=x+1
# Out:
# 0
# 1
# 2

# %%
x=0
while x<3:
   
    if x==1:
        break
    print(x)
    x=x+1
# Out:
# 0

# %%
x=0
while x<=10:
    print(x)
    if x==5:
        break
   
    x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=0
while x<=10:
    print("hi")
    print("bye")
    if x==5:
        continue
    print(x)   
    x=x+1
# Out:
# hi
# bye
# 0
# hi
# bye
# 1
# hi
# bye
# 2
# hi
# bye
# 3
# hi
# bye
# 4
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# hi
# bye
# ...

# %%
x=0
while x<4:
    
    x=x+1 
    if x==3:
        continue
    print(x)
# Out:
# 1
# 2
# 4

# %%
x=0
while x<4:
    if x==0:
        print("* * *")
    elif x==1:
        print("*   *")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*   *")
    else:
        print("* *")

    x=x+1
# Out:
# * * *
# *   *
# * * *
# *   *

# %%
x=0
while x<7:
    if x==0:
        print("* *")
    elif x==1:
        print("*   *")
    elif x==2:
        print("*  *")
    elif x==3:
        print("* *")
    elif x==4:
        print("*  *")
    elif x==5:
        print("*   *")
    elif x==6:
        print("* *")
    
    
    else:
        print("")

    x=x+1
# Out:
# * *
# *   *
# *  *
# * *
# *  *
# *   *
# * *

# %%
x=0
while x<7:
    if x==0:
        print("   * * *")
    elif x==1:
        print(" *")
    elif x==2:
        print("*")
    elif x==3:
        print("*")
    elif x==4:
        print("*")
    elif x==5:
        print(" *")
    elif x==6:
        print("   * * *")
    
    
    else:
        print("")

    x=x+1
# Out:
#    * * *
#  *
# *
# *
# *
#  *
#    * * *

# %%
x=0
while x<7:
    if x==0:
        print("*  * *  *")
    elif x==1:
        print("*         *")
    elif x==2:
        print("*          *")
    elif x==3:
        print("*          *")
    elif x==4:
        print("*          *")
    elif x==5:
        print("*         *")
    elif x==6:
        print("*  * *  *")
    
    
    else:
        print("")

    x=x+1
# Out:
# *  * *  *
# *         *
# *          *
# *          *
# *          *
# *         *
# *  * *  *

# %%
x=0
while x<5:
    if x==0:
        print("* * *")
    elif x==1:
        print("*   ")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*   ")
    elif x==4:
        print("* * * ")
    else:
        print("")

    x=x+1
# Out:
# * * *
# *
# * * *
# *
# * * *

# %%
x=0
while x<=4:
    if x==0:
        print("* * *")
    elif x==1:
        print("* ")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*   ")
    elif x==4:
        print("*   ")
    else:  
        print("")

    x=x+1
# Out:
# * * *
# *
# * * *
# *
# *

# %%
x=0
while x<7:
    if x==0:
        print("   * * *")
    elif x==1:
        print(" *")
    elif x==2:
        print("*")
    elif x==3:
        print("*")
    elif x==4:
        print("*     ******")
    elif x==5:
        print(" *     *   *")
    elif x==6:
        print("   * * *   *")
    
    
    else:
        print("")

    x=x+1
# Out:
#    * * *
#  *
# *
# *
# *     ******
#  *     *   *
#    * * *   *

# %%
x=0
while x<=4:
    if x==0:
        print("*   *")
    elif x==1:
        print("*   *")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*   *")
    elif x==4:
        print("*   *")
    else:
        print("")

    x=x+1
# Out:
# *   *
# *   *
# * * *
# *   *
# *   *

# %%
x=0
while x<=4:
    if x==0:
        print(" * * *")
    elif x==1:
        print("   * ")
    elif x==2:
        print("   *")
    elif x==3:
        print("   *   ")
    elif x==4:
        print(" * * *")
    else:
        print("")

    x=x+1
# Out:
#  * * *
#    *
#    *
#    *
#  * * *

# %%
x=0
while x<=4:
    if x==0:
        print(" * * * * *")
    elif x==1:
        print("     * ")
    elif x==2:
        print("     *")
    elif x==3:
        print("     *   ")
    elif x==4:
        print(" * * *")
    else:
        print("")

    x=x+1
# Out:
#  * * * * *
#      *
#      *
#      *
#  * * *

# %%
x=0
while x<=4:
    if x==0:
        print("*      *")
    elif x==1:
        print("*    *")
    elif x==2:
        print("* *")
    elif x==3:
        print("*    *")
    elif x==4:
        print("*      *")
    else:
        print("")

    x=x+1
# Out:
# *      *
# *    *
# * *
# *    *
# *      *

# %%
x=0
while x<=4:
    if x==0:
        print("*")
    elif x==1:
        print("* ")
    elif x==2:
        print("*")
    elif x==3:
        print("*   ")
    elif x==4:
        print("* * * * ")
    else:
        print("")

    x=x+1
# Out:
# *
# *
# *
# *
# * * * *

# %%
x=0
while x<=4:
    if x==0:
        print("**     **")
    elif x==1:
        print("*  *  * *")
    elif x==2:
        print("*   *   *")
    elif x==3:
        print("*       *")
    elif x==4:
        print("*       *")
    else:
        print("")

    x=x+1
# Out:
# **     **
# *  *  * *
# *   *   *
# *       *
# *       *

# %%
x=0
while x<=4:
    if x==0:
        print("**      *")
    elif x==1:
        print("*  *    *")
    elif x==2:
        print("*   *   *")
    elif x==3:
        print("*     * *")
    elif x==4:
        print("*       *")
    else:
        print("")

    x=x+1
# Out:
# **      *
# *  *    *
# *   *   *
# *     * *
# *       *

# %%
x=0
while x<7:
    if x==0:
        print("    *  *")
    elif x==1:
        print(" *       *")
    elif x==2:
        print("*         *")
    elif x==3:
        print("*         *")
    elif x==4:
        print("*         *")
    elif x==5:
        print(" *       *")
    elif x==6:
        print("   * * * ")
    
    
    else:
        print("")

    x=x+1
# Out:
#     *  *
#  *       *
# *         *
# *         *
# *         *
#  *       *
#    * * *

# %%
x=0
while x<=4:
    if x==0:
        print("* * *")
    elif x==1:
        print("*    *")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*   ")
    elif x==4:
        print("*   ")
    else:
        print("")

    x=x+1
# Out:
# * * *
# *    *
# * * *
# *
# *

# %%
x=0
while x<7:
    if x==0:
        print("    *  *")
    elif x==1:
        print(" *       *")
    elif x==2:
        print("*         *")
    elif x==3:
        print("*         *")
    elif x==4:
        print("*      *  *")
    elif x==5:
        print(" *      ****")
    elif x==6:
        print("   * * * ")
    
    
    else:
        print("")

    x=x+1
# Out:
#     *  *
#  *       *
# *         *
# *         *
# *      *  *
#  *      ****
#    * * *

# %%
x=0
while x<=4:
    if x==0:
        print("* * *")
    elif x==1:
        print("*    *")
    elif x==2:
        print("* * *")
    elif x==3:
        print("*    *   ")
    elif x==4:
        print("*      *   ")
    else:
        print("")

    x=x+1
# Out:
# * * *
# *    *
# * * *
# *    *
# *      *

# %%
x=0
while x<=4:
    if x==0:
        print("* * *")
    elif x==1:
        print("*    ")
    elif x==2:
        print("* * *")
    elif x==3:
        print("    *   ")
    elif x==4:
        print("* * *   ")
    else:
        print("")

    x=x+1
# Out:
# * * *
# *
# * * *
#     *
# * * *

# %%
x=0
while x<=4:
    if x==0:
        print(" * * * * *")
    elif x==1:
        print("     * ")
    elif x==2:
        print("     *")
    elif x==3:
        print("     *   ")
    elif x==4:
        print("     *   ")
    
    else:
        print("")

    x=x+1
# Out:
#  * * * * *
#      *
#      *
#      *
#      *

# %%
x=0
while x<=4:
    if x==0:
        print("*     *")
    elif x==1:
        print("*     *")
    elif x==2:
        print("*     *")
    elif x==3:
        print("*     *")
    elif x==4:
        print(" *  *  ")
    else:
        print("")

    x=x+1
# Out:
# *     *
# *     *
# *     *
# *     *
#  *  *

# %%
x=0
while x<=5:
    if x==0:
        print("*          *")
    elif x==1:
        print(" *        *")
    elif x==2:
        print("  *      *")
    elif x==3:
        print("   *    *")
    elif x==4:
        print("    *  *")
    elif x==5:
        print("     *")
    else:
        print("")

    x=x+1
# Out:
# *          *
#  *        *
#   *      *
#    *    *
#     *  *
#      *

# %%
x=0
while x<=5:
    if x==0:
        print("*          **            *")
    elif x==1:
        print(" *        *  *          *")
    elif x==2:
        print("  *      *    *        *")
    elif x==3:
        print("   *    *      *      *")
    elif x==4:
        print("    *  *        *    *")
    elif x==5:
        print("     *           * *")
    else:
        print("")

    x=x+1
# Out:
# *          **            *
#  *        *  *          *
#   *      *    *        *
#    *    *      *      *
#     *  *        *    *
#      *           * *

# %%
x=0
while x<=6:
    if x==0:
        print("*       *")
    elif x==1:
        print(" *    *")
    elif x==2:
        print("  *  *  ")
    elif x==3:
        print("   *   ")
    elif x==4:
        print("  *  *  ")
    elif x==5:
        print(" *     * ")
    elif x==6:
        print("*        * ")
    else:
        print("")

    x=x+1
# Out:
# *       *
#  *    *
#   *  *
#    *
#   *  *
#  *     *
# *        *

# %%
x=0
while x<=6:
    if x==0:
        print("*       *")
    elif x==1:
        print(" *    *")
    elif x==2:
        print("  *  *  ")
    elif x==3:
        print("   *   ")
    elif x==4:
        print("  *    ")
    elif x==5:
        print(" *      ")
    elif x==6:
        print("*         ")
    else:
        print("")

    x=x+1
# Out:
# *       *
#  *    *
#   *  *
#    *
#   *
#  *
# *

# %%
x=0
while x<=6:
    if x==0:
        print("  * * * * *")
    elif x==1:
        print("         *")
    elif x==2:
        print("       *  ")
    elif x==3:
        print("     *   ")
    elif x==4:
        print("   * * * * *      ")
    elif x==5:
        print("       ")
    elif x==6:
        print("         ")
    else:
        print("")

    x=x+1
# Out:
#   * * * * *
#          *
#        *
#      *
#    * * * * *
